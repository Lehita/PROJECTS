# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv(r"C:\Users\Sarah\Documents\EXTRA CURRICULAR\SHE CODE AFRICA\LungDataSet.csv", index_col=0)

# %%
data.head()
# Out:
#             Age  Gender  AirPollution  Alcoholuse  DustAllergy  \
# Patient Id
# P1           33       1             2           4            5
# P10          17       1             3           1            5
# P100         35       1             4           5            6
# P1000        37       1             7           7            7
# P101         46       1             6           8            7
#
#             OccuPationalHazards  GeneticRisk  chronicLungDisease  \
# Patient Id
# P1                            4            3                   2
# P10                           3            4                   2
# P100                          5            5                   4
# P1000                         7            6                   7
# P101                          7            7                   6
#
#             BalancedDiet  Obesity  ...  Fatigue  WeightLoss  \
# Patient Id                         ...
# P1                     2        4  ...        3           4
# ...

# %%
data.isnull().sum()
# Out:
# Age                      0
# Gender                   0
# AirPollution             0
# Alcoholuse               0
# DustAllergy              0
# OccuPationalHazards      0
# GeneticRisk              0
# chronicLungDisease       0
# BalancedDiet             0
# Obesity                  0
# Smoking                  0
# PassiveSmoker            0
# ChestPain                0
# CoughingofBlood          0
# Fatigue                  0
# WeightLoss               0
# ShortnessofBreath        0
# Wheezing                 0
# SwallowingDifficulty     0
# ClubbingofFingerNails    0
# FrequentCold             0
# DryCough                 0
# Snoring                  0
# Level                    0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, P1 to P999
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Age                    1000 non-null   int64
#  1   Gender                 1000 non-null   int64
#  2   AirPollution           1000 non-null   int64
#  3   Alcoholuse             1000 non-null   int64
#  4   DustAllergy            1000 non-null   int64
#  5   OccuPationalHazards    1000 non-null   int64
#  6   GeneticRisk            1000 non-null   int64
#  7   chronicLungDisease     1000 non-null   int64
#  8   BalancedDiet           1000 non-null   int64
#  9   Obesity                1000 non-null   int64
#  10  Smoking                1000 non-null   int64
#  11  PassiveSmoker          1000 non-null   int64
#  12  ChestPain              1000 non-null   int64
#  13  CoughingofBlood        1000 non-null   int64
#  14  Fatigue                1000 non-null   int64
# ...

# %%
data.describe().T
# Out:
#                         count    mean        std   min    25%   50%   75%  \
# Age                    1000.0  37.174  12.005493  14.0  27.75  36.0  45.0
# Gender                 1000.0   1.402   0.490547   1.0   1.00   1.0   2.0
# AirPollution           1000.0   3.840   2.030400   1.0   2.00   3.0   6.0
# Alcoholuse             1000.0   4.563   2.620477   1.0   2.00   5.0   7.0
# DustAllergy            1000.0   5.165   1.980833   1.0   4.00   6.0   7.0
# OccuPationalHazards    1000.0   4.840   2.107805   1.0   3.00   5.0   7.0
# GeneticRisk            1000.0   4.580   2.126999   1.0   2.00   5.0   7.0
# chronicLungDisease     1000.0   4.380   1.848518   1.0   3.00   4.0   6.0
# BalancedDiet           1000.0   4.491   2.135528   1.0   2.00   4.0   7.0
# Obesity                1000.0   4.465   2.124921   1.0   3.00   4.0   7.0
# Smoking                1000.0   3.948   2.495902   1.0   2.00   3.0   7.0
# PassiveSmoker          1000.0   4.195   2.311778   1.0   2.00   4.0   7.0
# ...

# %% [markdown]
# #### Gender is represented with integers, and attribute description was unavailable. So 1 is assumed to mean 'Male' and 2 is assumed to be 'Female'.

# %%
data["Gender"].replace(1,"Male",inplace=True)
data["Gender"].replace(2,"Female",inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, P1 to P999
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Age                    1000 non-null   int64
#  1   Gender                 1000 non-null   object
#  2   AirPollution           1000 non-null   int64
#  3   Alcoholuse             1000 non-null   int64
#  4   DustAllergy            1000 non-null   int64
#  5   OccuPationalHazards    1000 non-null   int64
#  6   GeneticRisk            1000 non-null   int64
#  7   chronicLungDisease     1000 non-null   int64
#  8   BalancedDiet           1000 non-null   int64
#  9   Obesity                1000 non-null   int64
#  10  Smoking                1000 non-null   int64
#  11  PassiveSmoker          1000 non-null   int64
#  12  ChestPain              1000 non-null   int64
#  13  CoughingofBlood        1000 non-null   int64
#  14  Fatigue                1000 non-null   int64
# ...

# %%
data.describe().T
# Out:
#                         count    mean        std   min    25%   50%   75%  \
# Age                    1000.0  37.174  12.005493  14.0  27.75  36.0  45.0
# AirPollution           1000.0   3.840   2.030400   1.0   2.00   3.0   6.0
# Alcoholuse             1000.0   4.563   2.620477   1.0   2.00   5.0   7.0
# DustAllergy            1000.0   5.165   1.980833   1.0   4.00   6.0   7.0
# OccuPationalHazards    1000.0   4.840   2.107805   1.0   3.00   5.0   7.0
# GeneticRisk            1000.0   4.580   2.126999   1.0   2.00   5.0   7.0
# chronicLungDisease     1000.0   4.380   1.848518   1.0   3.00   4.0   6.0
# BalancedDiet           1000.0   4.491   2.135528   1.0   2.00   4.0   7.0
# Obesity                1000.0   4.465   2.124921   1.0   3.00   4.0   7.0
# Smoking                1000.0   3.948   2.495902   1.0   2.00   3.0   7.0
# PassiveSmoker          1000.0   4.195   2.311778   1.0   2.00   4.0   7.0
# ChestPain              1000.0   4.438   2.280209   1.0   2.00   4.0   7.0
# ...

# %% [markdown]
# #### The range in the columns indicate 'severity' of the attribute. For example, chronic lung disease indicate severity of chronic lung disease. So, 1 means 'no chronic lung disease', 7 means 'very severe chronic lung disease'. Note that 'Level' refers to the lung cancer risk level, not the level of lung cancer.

# %%
data.describe(include=object).T
# Out:
#        count unique   top freq
# Gender  1000      2  Male  598
# Level   1000      3  High  365

# %%
#renaming column headers
data.rename(columns={"AirPollution":"Air pollution","Alcoholuse":"Alcohol use","DustAllergy":"Dust allergy","OccuPationalHazards":"Occupational hazards","GeneticRisk":"Genetic risk","chronicLungDisease":"Chronic lung disease","BalancedDiet":"Balanced diet","PassiveSmoker":"Passive smoker","ChestPain":"Chest pain","CoughingofBlood":"Coughing of Blood","WeightLoss":"Weight loss","ShortnessofBreath":"Shortness of breath","SwallowingDifficulty":"Swallowing difficulty","ClubbingofFingerNails":"Clubbing of finger nails","FrequentCold":"Frequent cold","DryCough":"Dry cough"},inplace=True)

# %%
#checking for duplicated patient info
data[data.index.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Age, Gender, Air pollution, Alcohol use, Dust allergy, Occupational hazards, Genetic risk, Chronic lung disease, Balanced diet, Obesity, Smoking, Passive smoker, Chest pain, Coughing of Blood, Fatigue, Weight loss, Shortness of breath, Wheezing, Swallowing difficulty, Clubbing of finger nails, Frequent cold, Dry cough, Snoring, Level]
# Index: []
#
# [0 rows x 24 columns]

# %% [markdown]
# ### EXPLORATORY DATA ANALYSIS

# %%
fig = plt.figure(figsize=(14,6))
ax1 = fig.add_subplot(1,2,2)
sns.countplot(data=data, x ="Level",hue="Gender",palette=['gray','cyan'])
plt.title("Count of Patients by Risk Level and Gender",fontsize=16,fontweight='bold')
plt.xlabel("Risk Level",fontsize=12)
plt.ylabel("Count of Patients",fontsize=12)
axs2 = fig.add_subplot(1,2,1)
sns.countplot(data=data, x="Level", color="gray")
plt.title("Count of Patients by Risk Level",fontsize=16,fontweight='bold')
plt.xlabel("Risk Level",fontsize=12)
plt.ylabel("Count of Patients",fontsize=12)
plt.show()

# %%
plt.figure(figsize=(14,6))
p = data.groupby("Gender")["Gender"].count().values
plt.pie(p,labels=["Female","Male"],labeldistance=None, startangle=90,explode=[0.07,0],colors=["cyan","gray"],autopct=lambda q: '{:.1f}%\n({:.0f})'.format(q,(q/100)*p.sum()),pctdistance=1.3)
plt.legend(title="Gender",loc="upper right")
plt.title("Count of Patients by Gender",fontsize=16,fontweight='bold')
plt.show()

# %%
plt.hist(data["Age"],bins=np.arange(min(data["Age"])-4,max(data["Age"])+7,5), color='gray')
plt.title("Age Distribution",fontsize=16,fontweight='bold')
plt.xlabel("Age",fontsize=12)
plt.ylabel("Frequency",fontsize=12)
plt.show()

# %%
data["Age"].sort_values()
# Out:
# Patient Id
# P615    14
# P315    14
# P13     14
# P115    14
# P215    14
#         ..
# P411    73
# P611    73
# P511    73
# P811    73
# P311    73
# Name: Age, Length: 1000, dtype: int64

# %% [markdown]
# #### The youngest patient is 14, while the oldest patient is 73

# %%
sns.violinplot(data=data,x="Gender",y="Alcohol use",palette=['gray','cyan'])
plt.title("Distribution of Alcohol Use by Gender",fontsize=16,fontweight='bold')
plt.xlabel("Gender",fontsize=12)
plt.ylabel("Alcohol Use",fontsize=12)
plt.show()

# %%
sns.set(style="whitegrid")
sns.violinplot(data=data,x="Gender",y="Chronic lung disease",palette=['gray','cyan'])
plt.title("Distribution of Chronic Lung Disease by Gender",fontsize=16,fontweight='bold')
plt.xlabel("Gender",fontsize=12)
plt.ylabel("Chronic Lung Disease",fontsize=12)
plt.show()

# %%
sns.pairplot(data, kind="reg", diag_kind='hist', vars=["Alcohol use","Occupational hazards","Chest pain","Genetic risk","Air pollution","Chronic lung disease","Coughing of Blood"],plot_kws={'color':'gray'},diag_kws={'color':'gray'})
plt.show()

# %%
sns.scatterplot(x="Occupational hazards",y="Dust allergy",data=data,hue="Level",palette=["gray","cyan","springgreen"])
plt.title("Dust Allergy VS Occupational Hazards",fontsize=16,fontweight='bold')
plt.xlabel("Occupational Hazards",fontsize=12)
plt.ylabel("Dust Allergy",fontsize=12)
plt.show()

# %%
sns.scatterplot(x="Genetic risk",y="Dust allergy",data=data,hue="Level",palette=["gray","cyan","springgreen"])
plt.title("Dust Allergy VS Genetic Risk",fontsize=16,fontweight='bold')
plt.xlabel("Genetic Risk",fontsize=12)
plt.ylabel("Dust Allergy",fontsize=12)
plt.show()

# %%
sns.violinplot("Balanced diet",data=data,palette="gray")
plt.title("Distribution of Balanced Diet",fontsize=16,fontweight='bold')
plt.xlabel("Balanced Diet",fontsize=12)
plt.show()

# %% [markdown]
# #### Most patients had very good diet (>5).

# %%
sns.scatterplot(x="Chest pain",y="Balanced diet",data=data,hue="Level",palette=["gray","cyan","springgreen"])
plt.title("Balanced Diet VS Chest Pain",fontsize=16,fontweight='bold')
plt.xlabel("Chest Pain",fontsize=12)
plt.ylabel("Balanced Diet",fontsize=12)
plt.show()

# %% [markdown]
# #### Balanced diet and chest pain are positively correlated. Patients with very good diet (>5) had a mix of medium and high risk of lung cancer.

# %%
sns.lmplot(x="Chest pain",y="Passive smoker",data=data,ci=None,scatter_kws={'color':'gray'},line_kws={'color':'gray'})
plt.title("Passive Smoker VS Chest Pain",fontsize=16,fontweight='bold')
plt.xlabel("Chest Pain",fontsize=12)
plt.ylabel("Passive Smoker",fontsize=12)
plt.show()

# %% [markdown]
# #### A passive smoker is someone who breaths in other people's tobacco smoke (second-hand smoke).

# %%
high = data[data["Level"] == 'High']
low = data[data["Level"] == 'Low']
medium = data[data["Level"] == 'Medium']

# %%
fig = plt.figure(figsize=(14,6))
ax = fig.add_subplot(221)
plt.hist(high["Age"],bins=np.arange(min(data["Age"])-4,max(data["Age"])+7,5),color='gray')
plt.title("Age Distribution of High Risk Patients",fontsize=16,fontweight='bold')
plt.xlabel("Age",fontsize=12)
plt.ylabel("Frequency",fontsize=12)
ax2 = fig.add_subplot(222)
plt.hist(low["Age"],bins=np.arange(min(data["Age"])-4,max(data["Age"])+7,5),color='gray')
plt.title("Age Distribution of Low Risk Patients",fontsize=16,fontweight='bold')
plt.xlabel("Age",fontsize=12)
plt.ylabel("Frequency",fontsize=12)
ax3 = fig.add_subplot(223)
plt.hist(medium["Age"],bins=np.arange(min(data["Age"])-4,max(data["Age"])+7,5),color='gray')
plt.title("Age Distribution of Medium Risk Patients",fontsize=16,fontweight='bold')
plt.xlabel("Age",fontsize=12)
plt.ylabel("Frequency",fontsize=12)
plt.subplots_adjust(hspace=0.7)
plt.show()

# %%
sns.lmplot(x="Coughing of Blood",y="Obesity",data=data,ci=None,scatter_kws={'color':'gray'},line_kws={'color':'gray'})
plt.title("Obesity VS Coughing of Blood",fontsize=16,fontweight='bold')
plt.xlabel("Coughing of Blood",fontsize=12)
plt.ylabel("Obesity",fontsize=12)
plt.show()

# %% [markdown]
# ### DATA PRE-PROCESSING

# %%
data.head()
# Out:
#             Age Gender  Air pollution  Alcohol use  Dust allergy  \
# Patient Id
# P1           33   Male              2            4             5
# P10          17   Male              3            1             5
# P100         35   Male              4            5             6
# P1000        37   Male              7            7             7
# P101         46   Male              6            8             7
#
#             Occupational hazards  Genetic risk  Chronic lung disease  \
# Patient Id
# P1                             4             3                     2
# P10                            3             4                     2
# P100                           5             5                     4
# P1000                          7             6                     7
# P101                           7             7                     6
#
#             Balanced diet  Obesity  ...  Fatigue  Weight loss  \
# Patient Id                          ...
# ...

# %%
#converting the gender and risk level columns to integers
data["Gender"].replace("Male",1,inplace=True)
data["Gender"].replace("Female",2,inplace=True)
data["Level"].replace("Low",0,inplace=True)
data["Level"].replace("Medium",1,inplace=True)
data["Level"].replace("High",2,inplace=True)

# %%
data.head()
# Out:
#             Age  Gender  Air pollution  Alcohol use  Dust allergy  \
# Patient Id
# P1           33       1              2            4             5
# P10          17       1              3            1             5
# P100         35       1              4            5             6
# P1000        37       1              7            7             7
# P101         46       1              6            8             7
#
#             Occupational hazards  Genetic risk  Chronic lung disease  \
# Patient Id
# P1                             4             3                     2
# P10                            3             4                     2
# P100                           5             5                     4
# P1000                          7             6                     7
# P101                           7             7                     6
#
#             Balanced diet  Obesity  ...  Fatigue  Weight loss  \
# Patient Id                          ...
# ...

# %% [markdown]
# ### FEATURE ENGINEERING

# %%
#using heatmaps
corr = data.corr()

# %%
plt.figure(figsize=(14,6))
sns.heatmap(data.corr(),annot=True,cmap='coolwarm')
plt.show()

# %% [markdown]
# #### Multicollinearity can be seen in the heatmap. Thus, I will not be using the heatmap to select features.

# %%
#using Extra trees classifier
x = data[data.columns[0:len(data.columns)-1]]
y = data["Level"]
from sklearn.ensemble import ExtraTreesClassifier
tree = ExtraTreesClassifier()
tree.fit(x,y)
print(tree.feature_importances_)
# Out:
# [0.00328471 0.00181193 0.04070299 0.06217156 0.04180393 0.03698786
#  0.04971626 0.03477276 0.06145781 0.08035974 0.04031766 0.07091069
#  0.0349793  0.08003703 0.05129522 0.03588354 0.03968039 0.05460893
#  0.05021476 0.03387833 0.03761827 0.02248305 0.03502328]

# %%
feat_importance = pd.Series(tree.feature_importances_,index=x.columns)
feat_importance.nlargest(15).plot(kind='barh')
col_of_interest = feat_importance.nlargest(15).index.tolist()
col_of_interest
# Out:
# ['Obesity',
#  'Coughing of Blood',
#  'Passive smoker',
#  'Alcohol use',
#  'Balanced diet',
#  'Wheezing',
#  'Fatigue',
#  'Swallowing difficulty',
#  'Genetic risk',
#  'Dust allergy',
#  'Air pollution',
#  'Smoking',
#  'Shortness of breath',
#  'Frequent cold',
#  'Occupational hazards']

# %%
#using SelectKBest
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
select = SelectKBest(score_func=chi2,k=15)
fit = select.fit_transform(x,y)
filters = x.columns[select.get_support()].to_list()
filters
# Out:
# ['Air pollution',
#  'Alcohol use',
#  'Dust allergy',
#  'Occupational hazards',
#  'Genetic risk',
#  'Chronic lung disease',
#  'Balanced diet',
#  'Obesity',
#  'Smoking',
#  'Passive smoker',
#  'Chest pain',
#  'Coughing of Blood',
#  'Fatigue',
#  'Shortness of breath',
#  'Clubbing of finger nails']

# %% [markdown]
# ### MODELLING

# %%
#splitting the data
features = data[col_of_interest]
target = data["Level"]
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(features, target, test_size=0.20,shuffle=False,random_state=0)

# %%
#reducing the dimensionality of the data
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
x_train = pca.fit_transform(x_train)
x_test = pca.transform(x_test)
print(pca.explained_variance_ratio_)
# Out:
# [0.50614538 0.11885856]

# %%
#training the model using Gaussian Naive Bayes
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import cross_validate
clf1 = GaussianNB()
scores = cross_validate(clf1,x_train,y_train,cv=4)
scores["test_score"].mean()
# Out:
# 0.6862499999999999

# %%
#training the model using SVC
from sklearn.svm import SVC
clf2 = SVC()
scores2 = cross_validate(clf2,x_train,y_train,cv=4)
scores2["test_score"].mean()
# Out:
# 0.9287500000000001

# %%
#training the model using DecisionTreeClassifier
from sklearn.tree import DecisionTreeClassifier
clf3 = DecisionTreeClassifier(max_depth=3)
scores3 = cross_validate(clf3,x_train,y_train,cv=4)
scores3["test_score"].mean()
# Out:
# 0.9275

# %%
from sklearn.ensemble import RandomForestClassifier
clf4 = RandomForestClassifier(max_depth=3, random_state=0)
scores4 = cross_validate(clf4,x_train,y_train,cv=4)
scores4["test_score"].mean()
# Out:
# 0.9275

# %%
from sklearn.linear_model import LogisticRegression
clf5 = LogisticRegression()
scores5 = cross_validate(clf5,x_train,y_train,cv=4)
scores5["test_score"].mean()
# Out:
# 0.765

# %%
#### choosing RandomForest classifier

# %%
import sklearn
clf = sklearn.base.clone(clf4)
clf.fit(x_train,y_train)
#checking the accuracy
from sklearn.metrics import confusion_matrix, accuracy_score
pred = clf.predict(x_test)
cm = confusion_matrix(y_test, pred)
print(cm)
accuracy_score(y_test, pred)
# Out:
# [[48 12  0]
#  [ 0 62  1]
#  [ 0  0 77]]
# 0.935
